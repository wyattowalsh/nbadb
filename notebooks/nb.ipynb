# %%
# %cd ..
# Out:
# /Users/ww/dev/projects/nba-db

# %%
# autoreload magic
# %load_ext autoreload
# %autoreload 2

# %%
from nbadb.nbaDbHelper import NbaDbHelper
# Out:
# /Users/ww/dev/projects/nba-db/.venv/lib/python3.11/site-packages/pyspark/pandas/__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %%
from nbadb.schemas import save_schemas
save_schemas()

# %%
helper = NbaDbHelper()
# Out:
# 🕸️ executed at: 2024-04-12 at 01:45:46 | module: mylogger ⇨ function: start_logger ⇨ line #: 84 |  elapsed time: 0:00:01.220315 | INFO ⇨ Logger initialized  🌎
# 🕸️ executed at: 2024-04-12 at 01:45:46 | module: proxyhelper ⇨ function: load_proxies ⇨ line #: 107 |  elapsed time: 0:00:01.224432 | INFO ⇨ Loaded 50 proxies from proxies.csv  🌎
# 🏀 executed at: 2024-04-12 at 01:45:46 | module: logging ⇨ function: start_logger ⇨ line #: 87 | elapsed time: 0:00:01.236088 | INFO ⇨ Logger initialized  ⛹️

# %%
players = helper.get_players()
players.head(3)
# Out:
# 🏀 executed at: 2024-04-12 at 01:45:47 | module: nbaDbHelper ⇨ function: get_players ⇨ line #: 161 | elapsed time: 0:00:02.059581 | INFO ⇨ Fetching players data...  ⛹️
# 🏀 executed at: 2024-04-12 at 01:45:47 | module: nbaDbHelper ⇨ function: get_players ⇨ line #: 167 | elapsed time: 0:00:02.078831 | INFO ⇨ Successfully fetched 4900 players.  ⛹️
# 🏀 executed at: 2024-04-12 at 01:45:47 | module: nbaDbHelper ⇨ function: write_to_db ⇨ line #: 146 | elapsed time: 0:00:02.100885 | INFO ⇨ Players table updated.  ⛹️
# 🏀 executed at: 2024-04-12 at 01:45:48 | module: nbaDbHelper ⇨ function: get_teams ⇨ line #: 184 | elapsed time: 0:00:02.893196 | INFO ⇨ Fetching teams data...  ⛹️
# 🏀 executed at: 2024-04-12 at 01:45:48 | module: nbaDbHelper ⇨ function: get_teams ⇨ line #: 190 | elapsed time: 0:00:02.902861 | INFO ⇨ Successfully fetched 30 teams.  ⛹️
# ...

# %%
teams = helper.get_teams()
teams.head(3)
# Out:
#       TEAM_ID            FULL_NAME ABBREVIATION   NICKNAME       CITY  \
# 0  1610612737        Atlanta Hawks          ATL      Hawks    Atlanta
# 1  1610612738       Boston Celtics          BOS    Celtics     Boston
# 2  1610612739  Cleveland Cavaliers          CLE  Cavaliers  Cleveland
#
#            STATE YEAR_FOUNDED
# 0        Georgia         1949
# 1  Massachusetts         1946
# 2           Ohio         1970

# %%
helper = NbaDbHelper()
tds =  helper.get_team_details()
# Out:
# 🕸️ executed at: 2024-04-12 at 01:53:52 | module: mylogger ⇨ function: start_logger ⇨ line #: 84 |  elapsed time: 0:08:06.994411 | INFO ⇨ Logger initialized  🌎
# 🕸️ executed at: 2024-04-12 at 01:53:52 | module: proxyhelper ⇨ function: load_proxies ⇨ line #: 107 |  elapsed time: 0:08:06.996817 | INFO ⇨ Loaded 50 proxies from proxies.csv  🌎
# 🕸️ executed at: 2024-04-12 at 01:53:52 | module: proxyhelper ⇨ function: get_proxies ⇨ line #: 134 |  elapsed time: 0:08:06.997628 | INFO ⇨ Proxies file is outdated, fetching new proxies.  🌎
# 🕸️ executed at: 2024-04-12 at 01:53:52 | module: proxyhelper ⇨ function: get_proxies_helper ⇨ line #: 63 |  elapsed time: 0:08:06.997805 | INFO ⇨ Fetching proxies...  🌎
# 2024-04-12 01:53:53.527 | INFO     | pyproxyhelper.providers.proxyscrape:get_proxies:21 - Getting proxies from ProxyScrape
# 2024-04-12 01:53:53.527 | INFO     | pyproxyhelper.providers.scrapingant:get_proxies:22 - Getting proxies from ScrapingAnt
# ...

# %%
tds.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 tds.keys()
#
# AttributeError: 'NoneType' object has no attribute 'keys'

# %%
tds[ 'TeamRetired' ]
# Out:
#      PLAYERID          PLAYER POSITION JERSEY SEASONSWITHTEAM  YEAR  \
# 0       708.0   Kevin Garnett        F      5       2008-2013  2022
# 1      1718.0     Paul Pierce        F     34       1999-2013  2018
# 2     77487.0  Cedric Maxwell        F     31       1978-1985  2003
# 3       305.0   Robert Parish        C     00       1981-1994  1998
# 4      1450.0    Kevin McHale        F     32       1981-1993  1994
# ..        ...             ...      ...    ...             ...   ...
# 115   76386.0    Phil Chenier        G   None       1972-1979  2018
# 116  600006.0     Earl Monroe        G     10       1968-1972  2007
# 117   77150.0     Gus Johnson        F     25       1964-1972  1986
# 118   76979.0     Elvin Hayes        F     11       1973-1981  1981
# 119   78392.0      Wes Unseld        C     41       1969-1981  1981
#
#         TEAM_ID
# 0    1610612737
# 1    1610612737
# 2    1610612737
# 3    1610612737
# 4    1610612737
# ..          ...
# 115  1610612753
# ...

# %%
players[players['PLAYER_ID'] == '708']
# Out:
#      PLAYER_ID      FULL_NAME FIRST_NAME LAST_NAME  IS_ACTIVE
# 1467       708  Kevin Garnett      Kevin   Garnett      False

# %%
pd.to_datetime(tds[ 'TeamBackground' ]['YEARFOUNDED'], format='%Y').dt.year
# Out:
# 0     1946
# 1     2002
# 2     1966
# 3     1946
# 4     1967
# 5     1970
# 6     1976
# 7     1989
# 8     1976
# 9     1968
# 10    1970
# 11    1976
# 12    1967
# 13    1995
# 14    1974
# 15    1995
# 16    1961
# Name: YEARFOUNDED, dtype: int32
